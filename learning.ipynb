# %%
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
with open('centralasia.txt', errors="ignore") as file:
    file_contents = file.read()

# %%
file_in_words = word_tokenize(file_contents)

stop_words=set(stopwords.words("english"))


filtered_sent=[]
for w in file_in_words:
    if len(w) <= 4:
        continue
    if w not in stop_words:
        filtered_sent.append(w)

fdist = FreqDist(filtered_sent)
print(fdist)
print(fdist.most_common(5))
# Out:
# <FreqDist with 26893 samples and 125794 outcomes>
# [('GOOGLE', 1652), ('Central', 725), ('around', 564), ('Kazakhstan', 539), ('hours', 469)]

# %%
fdist.plot(40,cumulative=False)
plt.show()

# %%
from nltk.text import Text  

text1 = Text(file_in_words)

# %%
text1.concordance("off the beaten track")
# Out:
# no matches
