# %% [markdown]
# this notebook contains my notes from http://www.nltk.org/book/

# %%
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %% [markdown]
# how to open file so it is readable for nltk:

# %%
with open('centralasia.txt', errors="ignore") as file:
    file_contents = file.read()

# %% [markdown]
# file needs to be tokenized so words can be evaluated (otherwise, letters will be evaluated):

# %%
file_in_words = word_tokenize(file_contents)

# %% [markdown]
# exclude stopwords (english language) and list most frequent words:

# %%
stop_words = set(stopwords.words("english"))

filtered_sent=[]
for w in file_in_words:
    if len(w) <= 4:
        continue
    if w == "GOOGLE":
        continue
    if w not in stop_words:
        filtered_sent.append(w)

fdist = FreqDist(filtered_sent)
print(fdist)
print(fdist.most_common(50))
# Out:
# <FreqDist with 26892 samples and 124142 outcomes>
# [('Central', 725), ('around', 564), ('Kazakhstan', 539), ('hours', 469), ('There', 417), ('Uzbekistan', 411), ('Kyrgyzstan', 392), ('local', 331), ('border', 315), ('Tajikistan', 311), ('Russian', 305), ('Almaty', 302), ('Valley', 290), ('Soviet', 289), ('Tashkent', 279), ('place', 264), ('three', 260), ('region', 255), ('Turkmenistan', 250), ('country', 244), ('centre', 238), ('along', 234), ('Bishkek', 232), ('station', 230), ('daily', 223), ('Astana', 222), ('including', 222), ('rooms', 219), ('Bukhara', 218), ('south', 218), ('Kyrgyz', 214), ('though', 214), ('across', 211), ('Uzbek', 210), ('small', 210), ('Samarkand', 209), ('travellers', 208), ('shared', 198), ('travel', 194), ('village', 191), ('north', 188), ('summer', 187), ('Mon-Fri', 187), ('century', 183), ('often', 183), ('taxis', 182), ('train', 181), ('mains', 175), ('great', 173), ('Asian', 172)]

# %%
fdist.plot(40,cumulative=False)
plt.show()

# %%
fdist.plot(40, cumulative=True)

# %% [markdown]
# "concordance": see occurences of a specified word in its context:

# %%
from nltk.text import Text  

text1 = Text(file_in_words)

# %%
text1.concordance("beaten")
# Out:
# Displaying 23 of 23 matches:
# ars . Head even a little bit off the beaten track and you 'll likely have the pl
# ple live . Budget travellers off the beaten track may still have to use the occa
# he banks of the Oxus River . Off the Beaten Track Central Asia 's remoter gems t
# streets . If you want to get off the beaten track make a detour to Nurata and th
# Z MASLANKA / SHUTTERSTOCK Â© OFF THE BEATEN TRACK IN UZBEKISTAN Aral Sea Getting
# d offer exciting ways to get off the beaten track without blowing your budget .
# are great and the location ca n't be beaten ; plus there 's a small outdoor spac
# e valley as a one-day walk . OFF THE BEATEN TRACK ATA-BEYIT MEMORIAL COMPLEX The
# r details and reservations . OFF THE BEATEN TRACK WINTER SPORTS AROUND BISHKEK A
# troglyphs that are still far off the beaten tourist trail . For visitors headed
# om plus ski lift tickets ) . OFF THE BEATEN TRACK PRISTAN PRZHEVALSK Karakol 's
# 5-311511 ) and other firms . OFF THE BEATEN TRACK HIKING TO KÃ–L-ÃœKÃ–K The beau
# dependently or through CBT . OFF THE BEATEN TRACK SAIMALUU TASH PETROGLYPHS The
# next morning at around 6am . OFF THE BEATEN TRACK MOUNTAIN VILLAGE HOMESTAYS The
# /2TJS for short/long rides . OFF THE BEATEN TRACK GARAM CHASHMA HOT SPRINGS For
# a lot of time and patience . OFF THE BEATEN TRACK THE AFGHAN WAKHAN VALLEY Unlik
# own 's charm . Termiz is way off the beaten track but has some intriguing remain
#  one way to the yurt camps . OFF THE BEATEN TRACK HOMESTAY HIKING IN THE NURATAU
# nder the stars and exploring off the beaten track . From the car park where you
# ond day for around 40,000T . OFF THE BEATEN TRACK ISSYK KURGANS Some 69km east o
# e North Inylchek base camp . OFF THE BEATEN TRACK TAMGALY PETROGLYPHS The World
# s in English are available . OFF THE BEATEN TRACK SAURAN Some 48km northwest of
# ple live . Budget travellers off the beaten track may still have to use the occa

# %% [markdown]
# A concordance permits us to see words in context. For example, we saw that monstrous occurred in contexts such as the ___ pictures and a ___ size . What other words appear in a similar range of contexts? We can find out by appending the term similar to the name of the text in question, then inserting the relevant word in parentheses:

# %%
text1.similar("mountains")
# Out:
# region border valley country bazaar centre city pamirs road south
# airport route century river east village town way north area

# %% [markdown]
# Observe that we get different results for different texts. Austen uses this word quite differently from Melville; for her, monstrous has positive connotations, and sometimes functions as an intensifier like the word very.
#
# The term common_contexts allows us to examine just the contexts that are shared by two or more words, such as monstrous and very. We have to enclose these words by square brackets as well as parentheses, and separate them with a comma:

# %%
text1.common_contexts(["mountains", "villages"])
# Out:
# the_of surrounding_there the_around

# %% [markdown]
# we can also determine the location of a word in the text: how many words from the beginning it appears. This positional information can be displayed using a dispersion plot. Each stripe represents an instance of a word, and each row represents the entire text.
#
# In 1.2 we see some striking patterns of word usage over the last 220 years (in an artificial text constructed by joining the texts of the Inaugural Address Corpus end-to-end).

# %%
text1.dispersion_plot(["mountains", "beaten", "secret", "Central"])

# %%
# vocabulary:
print(len(set(text1)))
# Out:
# 31504

# %% [markdown]
# Now, let's calculate a measure of the lexical richness of the text. The next example shows us that the number of distinct words is just 6% of the total number of words, or equivalently that each word is used 16 times on average

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

def percentage(count, total):
    return 100 * count / total

# %% [markdown]
# show words that occur only once:

# %%
fdist.hapaxes()
# Out:
# ['Contents',
#  'Survive',
#  'kinetic',
#  'instinctive',
#  'discovery',
#  'fascination',
#  'pivot',
#  'Footprints',
#  'page-turning',
#  'litters',
#  'skylines',
#  'limitless',
#  'synonymous',
#  'wanderer',
#  'oddities',
#  '¿Bukhara',
#  'CHEKUNOV',
#  'ALEKSANDR',
#  '/SHUTTERSTOCK',
#  'sand-prints',
#  'engagement',
#  'Stan-oholic',
#  'Bathhouse',
#  'petrodollar',
#  'THERIN-WEISE',
#  'custom-built',
#  'mirage',
#  'glass-pyramid',
#  'post-Borat',
#  'Sweeney',
#  'fuelling',
#  'silly',
#  'MARIUSZ',
#  'PRUSACZYK',
#  'ALAMY',
#  'STOCK',
#  'PHOTO',
#  'vice-like',
#  'CHAPPLE',
#  'spreads',
#  'MICHAL',
#  'KNITL',
#  'IRYNA',
#  'HROMOTSKA',
#  'khaki',
#  'EFESENKO',
#  'pulverised',
#  'DARKYDOORS',
#  "'wild",
#  'Kara-KÃ¶l',
#  'Tackle',
#  'NOWAK',
#  'LUKASZ',
#  'DUDAREV',
#  'MIKHAIL',
#  'high-alpine',
#  'fringed',
#  'TDWAY',
#  'Untouched',
#  'FLASKER',
#  'DMITRY',
#  'CHULOV',
#  'Shangri-La',
#  'Bordered',
#  'Aprâ€',
#  'Sepâ€',
#  'Shoulder',
#  'ASizzlingly',
#  'APrime',
#  'Novâ€',
#  'ACold',
#  'AMany',
#  'AMarch',
#  'weather-wise',
#  'Websites',
#  'www.lonelyplanet.com',
#  'Peerless',
#  'Virtual',
#  'EurasiaNet',
#  'www.eurasianet.org',
#  'Pamirs.org',
#  'Definitive',
#  'Safely',
#  'AHomestay',
#  'AChaikhana',
#  'ATour',
#  '150â€',
#  'AGive',
#  'amass',
#  'AInform',
#  'debit-/credit-card',
#  'phrasebook',
#  'APostcards',
#  'AFloss',
#  'ALearn',
#  'travelogue',
#  'Clothing',
#  'Working',
#  'Blowing',
#  'Respect',
#  'Loose-fitting',
#  'car-hire',
#  'www.thorntree.lonelyplanet.com',
#  'box-like',
#  'corkscrew',
#  'head-spinning',
#  'turquoise-blue',
#  'Singularly',
#  '¿Shah-i-Zinda',
#  '¿Samarkand',
#  'NICOLA',
#  'MESSANA',
#  'PHOTOS',
#  'hiding',
#  'Jewel-like',
#  'KÃ¶l-Mazar',
#  '¿Yurt',
#  '¿Karakul',
#  'reciting',
#  'Kyrgyz-style',
#  'kiss-chase',
#  'hunts',
#  'berkutchi',
#  'Haggling',
#  'white-beards',
#  '¿Chaikhana',
#  'BRUNO',
#  'MORANDI',
#  'Pioneering',
#  'countrywide',
#  'bulky',
#  'wildlife-watching',
#  'Penjiken',
#  'once-cosmopolitan',
#  'Beaten',
#  'Track',
#  "'Stan",
#  'necropoli',
#  'enigmatically',
#  "'Valley",
#  'Balls',
#  'two-millennia-old',
#  'sandcastles',
#  'Gorgeous',
#  'myths',
#  'Downright',
#  'blast',
#  'Kazakstan',
#  'folly',
#  'innards',
#  'fiery',
#  'post-apocalyptic',
#  'Atomic',
#  'Immersion',
#  'Sweat',
#  'birch-branch',
#  'watermelon',
#  'Babushkas',
#  'liturgies',
#  'bucks',
#  'Celebrations',
#  'Perfect',
#  'zNauroz',
#  'feasts',
#  'funfairs',
#  '¿Shirinliklar',
#  'ARMASTAS',
#  '3Bishkek',
#  'attending',
#  '3Horse',
#  'hippodromes',
#  'zSilk',
#  'Four-day',
#  'walker',
#  '2Watching',
#  'Madin',
#  'Rakhimzhan',
#  'zAstana',
#  'zNational',
#  'zRoof',
#  '2Roof',
#  'windsurfer',
#  'kayak',
#  'regatta',
#  '3Birds',
#  'Third',
#  'zFourE',
#  'alternative-lifestyle',
#  'www.foure.kz/en',
#  '3Sharq',
#  "'Melodies",
#  'Markets',
#  '3World',
#  'www.worldnomadgames.com',
#  '¿Kazakhstan',
#  'ALEXANDR',
#  'VLASSYUK',
#  'pageantry',
#  'shivers',
#  'sub-zero',
#  'Concerts',
#  'conferences',
#  'Cities',
#  'crumbing',
#  'tarmac',
#  'decisions',
#  'breathed',
#  'tulip-spotting',
#  'hitting',
#  'ogling',
#  'Oceanarium',
#  '1700km',
#  'mountain-road',
#  'detours',
#  'storybook',
#  'detouring',
#  'Caravanserais',
#  'roller-coaster',
#  'eagle-hunter',
#  "'start",
#  'Easily',
#  'Specify',
#  'date-specific',
#  'prebooked',
#  'entry/exit',
#  'AAnywhere',
#  'passport-size',
#  'AProof',
#  'tourist-visa',
#  'fixed-entry',
#  'fixed-validity',
#  'double-',
#  'retaliation',
#  "multi-'Stan",
#  'screw-ups',
#  'Errors',
#  '¿Palace',
#  '¿Reconciliation',
#  '¿Astana',
#  'MEIRAM',
#  'NURTAZIN',
#  'Letters',
#  'longer-duration',
#  "'visa",
#  'Individual',
#  'visa-required',
#  'fly-in',
#  'invitees',
#  'scribbled',
#  'GETTING',
#  'CURRENT',
#  'ACaravanistan',
#  'AThorn',
#  'www.lonelyplanet.com/thorntree',
#  'www.kazakhembus.com',
#  'www.kazconsulny.org',
#  'www.kazembassy.org.uk',
#  'www.mfa.gov.kz/en',
#  'www.kgembassy.org',
#  'www.kyrgyz-embassy.org.uk',
#  'www.botschaft-kirgisien.de',
#  'ATajikistan',
#  'www.tajemb.us',
#  'www.tajikembassy.be',
#  'www.tajembassy.org.uk',
#  'www.botschaft-tadschikistan.de',
#  'www.turkmenistanembassy.org',
#  'www.turkmenembassy.org.uk',
#  'www.uzbekconsulny.org',
#  'www.uzbekistan.org',
#  'www.uzbekistan.de',
#  'www.uzbekembassy.org',
#  'www.ouzbekistan.fr',
#  'VISAS',
#  'employers',
#  'Multiple-Entry',
#  'ATourist-visa',
#  'policing',
#  'AAreas',
#  'ABaykonur',
#  'AVisits',
#  'opting',
#  'tiresome',
#  'preplanning',
#  'Scenic',
#  'Turkmenistanâ€',
#  'Headache',
#  'Karamyk/Jirgital',
#  'colander',
#  'trainload',
#  'convoluted',
#  'JIGSAW',
#  'BORDERS',
#  'portioned',
#  'whims',
#  'horse-trading',
#  'once-complex',
#  'shrank',
#  'borderlines',
#  'Shakhimardan',
#  'disentangling',
#  'isolate',
#  'midafternoon',
#  'AChinese',
#  'ARussian',
#  'ABeware',
#  'Means',
#  'Comments',
#  'car/rail',
#  'Mary/Merv',
#  'upgrade',
#  'Dostyk/Alashankou',
#  'Maykapshagay/Jeminay',
#  'Jimunai',
#  'Little-used',
#  'Tricky',
#  'Termiz/Hayratan',
#  'Passenger-carrying',
#  'pasturelands',
#  'tracts',
#  'Birdwatching',
#  'Medeu',
#  'outrageously',
#  'whammy',
#  'less-visited',
#  'Sokuluk',
#  'Sarala-Saz',
#  'Jasy-KÃ¶l',
#  'Kaindy',
#  'Rivak',
#  'USEFUL',
#  'WEBSITES',
#  'www.pamirs.org/trekking.htm',
#  'www.pamirs.wordpress.com',
#  'Dated',
#  'Self-supported',
#  'Organisations',
#  'multifuel',
#  'folder',
#  'detailing',
#  'Trustworthy',
#  'competent',
#  'KAZAKHSTAN',
#  'Earthquake-formed',
#  'scorching',
#  'mined',
#  'trekking/climbing',
#  '1:150,000',
#  'Alpenvereinskarte',
#  'Gecko',
#  'Trans',
#  '1:200,000',
#  'Unclassified',
#  'steeper',
#  'grade',
#  'KYRGYZSTAN',
#  'SPECTACULAR',
#  'LAKES',
#  'shimmering',
#  'reflections',
#  'peak-packed',
#  'impression',
#  'Largest',
#  'Asku-Dzhabagly',
#  'sublimely',
#  'Horseback',
#  'Chekildek',
#  'six-day',
#  'Ak-Terek',
#  'Asiarando',
#  'www.asiarando.com',
#  'TRADITIONAL',
#  'TURKMEN',
#  'three-course',
#  'diehard',
#  'do-it-yourselfers',
#  'pedalling',
#  'extorted',
#  'Awww.carryoncycling.com',
#  'Awww.crazyguyonabike.com/doc/standiet',
#  'Awww.travellingtwo.com/resources/kyrgyzstan',
#  'Intrepid',
#  'rafters',
#  'kayakers',
#  'OUTDOOR',
#  'vehicle-free',
#  'kite-surfers',
#  'kayyakers',
#  'swimmers',
#  'Climbing',
#  "'alpinism",
#  "'Snow",
#  'climber',
#  'nontechnical',
#  'www.asiamountains.net',
#  'Ak-Say',
#  '4000m-plus',
#  'Experienced',
#  'Climber',
#  'Garth',
#  'Willis',
#  'Gamache',
#  'miniguide',
#  'least-known',
#  'Patagonia',
#  'Zamin-Karkor',
#  'www.alpin-ism.com/courses/expeditions/virgin-peaks-expedition',
#  'exploratory',
#  'Adrian',
#  'Nelhams',
#  'GIRAFFES_FLY',
#  'compare',
#  'speed-skating',
#  'rinks',
#  'shines',
#  'skidoo',
#  'Tribes',
#  'Backcountry',
#  'Freeride',
#  'deep-freeze',
#  'boards',
#  "'while",
#  'adventure-sports-related',
#  'HeliPro',
#  '555-966775',
#  '//helipro.kg',
#  'Four-Wheel',
#  'indestructible',
#  'Four-wheel',
#  'gorgeously',
#  'sandier',
#  'bashing',
#  'starry',
#  'MILOSZ',
#  'MASLANKA',
#  'caving',
#  'Spelunkers',
#  'tunnels',
#  'Karlyuk',
#  'Caves',
#  'scuba',
#  'props',
#  'Jacques',
#  'Cousteau',
#  'spotting',
#  'wetlands',
#  'tour-operator',
#  'Awww.kazakhstanbirdtours.com',
#  'Awww.naturetrek.co.uk',
#  'Awww.wingsbirds.com',
#  'Enjoy',
#  'knowing',
#  'Contacts',
#  'Eco-Cultural',
#  'mutually',
#  'beneficial',
#  'Helvetas',
#  'gung-ho',
#  'Program',
#  'sustain',
#  'teething',
#  'financially',
#  'self-supporting',
#  'COMMUNITY-BASED',
#  'ADVENTURES',
#  'AHikes',
#  'ecotourism-base',
#  'AExcursions',
#  'hike/horse',
#  'Programs',
#  'CBT-inspired',
#  'horse-racing',
#  'fixed-price',
#  'devoid',
#  'Societies',
#  'Support',
#  'MSDSP',
#  'Nurata-Kyzylkum',
#  'well-beaten',
#  'flexibility',
#  'vowel-challenged',
#  'outdoorsy',
#  'gazillion',
#  'Scrabble',
#  'Fabulous',
#  'blanks',
#  "'North",
#  'Splendour',
#  'Forested',
#  'Community-based',
#  'unlock',
#  'criss-cross',
#  'pitch-perfect',
#  'Drives',
#  'shashlyk-scented',
#  'Emirs',
#  'despotic',
#  'unmissable',
#  'standouts',
#  'Offbeat',
#  'Heartland',
#  'sub-Siberia',
#  'littered',
#  'ÐšÑ‹Ñ€Ð³Ñ‹Ð·ÑÐºÐ°Ñ',
#  'ÐµÑÐ¿ÑƒÐ±Ð',
#  'Ð¸ÐºÐ°',
#  'Joyously',
#  'unspoilt',
#  'yurt-dwelling',
#  'well-developed',
#  'never-freezing',
#  'AJulâ€',
#  'Ideal',
#  'stiflingly',
#  'ADecâ€',
#  'Rural',
#  'Chaikana',
#  'Navat',
#  'Pur-Pur',
#  'Tsarskii',
#  'Southside',
#  'Marginally',
#  'AStreet',
#  'ASelf-service',
#  'AFull',
#  '1800â€',
#  'share-taxi',
#  '300â€',
#  '250â€',
#  'Inilchek',
#  'pointers',
#  '199,990',
#  '53.98som',
#  '54.06som',
#  '10.31som',
#  '80.88som',
#  '62.38som',
#  '50.13som',
#  '1.15som',
#  '88.65som',
#  '68.85som',
#  '//gokg.asia',
#  'Tenti',
#  '//tenti.kg',
#  'Stargazing',
#  'experiencing',
#  'scaling',
#  'Experiencing',
#  '988,300',
#  'Delightfully',
#  'anachronisms',
#  'appreciation',
#  'peshagakh',
#  'â€˜place',
#  'mountainsâ€™',
#  'pishkek/bishkek',
#  'plunger-equipped',
#  'kymys-churn',
#  'etymological',
#  'theories',
#  'speech',
#  'grammar',
#  'Kievskaya',
#  'Moskovskaya',
#  'Baytik-Baatyr',
#  'Tynchtyk',
#  '1State',
#  'ArtsG2',
#  '2Ala-Too',
#  'SquareF3',
#  '3CircusG2',
#  '4Dubovy',
#  'ParkF2',
#  '5Frunze',
#  'House-MuseumF2',
#  '6Lenin',
#  'StatueF2',
#  '7National',
#  'MuseumF2',
#  '8Nissa',
#  'SalonF2',
#  'BazaarA3',
#  '10Statue',
#  'DatkaF2',
#  '11Victory',
#  'SquareH2',
#  '12White',
#  'HouseE3',
#  '13TUKC3',
#  '14Zhirgal',
#  'BanyaH3',
#  '15Asia',
#  '16BUGU',
#  '17Capsule',
#  'HotelF5',
#  '18Central',
#  '19Grand',
#  '20Hotel',
#  'SayrakeG2',
#  '21InterHouseD2',
#  '22Lotus',
#  'GuesthouseB1',
#  '23Silk',
#  '24Urmat',
#  'OrdoD3',
#  '25Viva',
#  'HostelA2',
#  '26Ak-BataH2',
#  '27Burger',
#  'HouseF3',
#  '28Chaikana',
#  'NavatE3',
#  '29Chaikhana',
#  'Jalal-AbadE3',
#  '30Chicken',
#  'StarF3',
#  '31DerevyashkaD2',
#  '32Frunze',
#  'RestaurantF2',
#  '33FurusatoF5',
#  'PizzaE3',
#  '35OrdoG3',
#  '36Plov',
#  'CenterF5',
#  '37Pur-PurD2',
#  'KitchenD2',
#  '38SlimFitF3',
#  '39VinotekaD3',
#  '40Vkys',
#  'VostokaH4',
#  '41CoffeÃ©E2',
#  '42CoffeÃ©D4',
#  '43Craft',
#  'CoffeeC3',
#  '44Metro',
#  'PubC3',
#  '45MÃ¼nchen',
#  'PubG3',
#  '46Pinta',
#  'PubD2',
#  'CoffeeE3',
#  '48Save',
#  'AlesG4',
#  '49Sierra',
#  'ManasD3',
#  '50Staryy',
#  'EdgarG2',
#  '51Vanilla',
#  'SkyD4',
#  '52Zolden',
#  'PubF3',
#  '53Kyrgyz',
#  'TheatreF2',
#  '54PhilharmoniaD2',
#  '55Russian',
#  '56State',
#  '57Akbara',
#  'StudioF4',
#  '58Asia',
#  'GalleryF3',
#  '59Bishkek',
#  'MallD3',
#  '60Clothing',
#  'StallsA3',
#  '61EposE3',
#  '62Frunze',
#  'HypermarketF5',
#  '63Kyrgyz',
#  'OyuE3',
#  '64Narodnyy/ShumkurD3',
#  '65RaritetF3',
#  '66Red',
#  'FoxH3',
#  '67SaimaD3',
#  '68TsUMG3',
#  '69Tumar',
#  'SalonD3',
#  '70AdvantourD3',
#  'TravelH3',
#  '71ARI',
#  'CargoD4',
#  '72C.A.T.E3',
#  '73Canadian',
#  'ConsulateC4',
#  '74Currency',
#  'ExchangeG4',
#  '75Demir',
#  'BankG4',
#  'DHLD3',
#  '76Diplomat',
#  'PharmacyD3',
#  '77FedExB4',
#  '78French',
#  '79German',
#  '80Indian',
#  'EmbassyB1',
#  '81Iranian',
#  '82ITMC',
#  'ShanB4',
#  '83Japanese',
#  '84KICB',
#  'BankF4',
#  '85Kyrgyz',
#  'ConceptG3',
#  '86Ministry',
#  'CultureG2',
#  '87Ministry',
#  'AffairsE3',
#  '88NeomedF4',
#  '89NoviNomadE3',
#  '90Optima',
#  'BankE3',
#  '91OVIRG3',
#  '92Persia',
#  'AgencyG4',
#  '93Russian',
#  '94Turkish',
#  'EmbassyG4',
#  '96Avia',
#  'ClubF5',
#  '97C.A.T',
#  'BranchD3',
#  '98China',
#  'AirlinesD3',
#  '99FlyDubaiD4',
#  '100Informal',
#  'OshA3',
#  '101Marshrutka',
#  'Ala-ArchaA3',
#  '102Marshrutka',
#  'BorderH3',
#  '103Marshrutka',
#  'AirportB2',
#  '104S7E4',
#  '105Turkish',
#  'AirlinesG5',
#  '106Uzbekistan',
#  'AirwaysD3',
#  '107Velo',
#  'LeaderB4',
#  '108VeloproC3',
#  '109Western',
#  'StationA1',
#  'half-hearted',
#  'lumps',
#  'spired',
#  'ArtsGALLERY',
#  'Aitiev',
#  '312-661544',
#  '//knmii.kg',
#  'adult/student',
#  '100/40som',
#  '10-5pm',
#  'Collections',
#  'SquareMONUMENT',
#  'Shopokov',
#  'struts',
#  'curving',
#  'dauntingly',
#  'sun-bleached',
#  '312-681808',
#  '//circus.312.kg',
#  'Jumabek',
#  '312-660604',
#  'admission/photography',
#  '100/110som',
#  'thatched',
#  'Vasilievich',
#  '1885â€',
#  "'Frunze",
#  'Surveyed',
#  'triumphant',
#  'ÐÐ¹ÐºÐ¾Ð',
#  'ÐœÐ°Ð½Ð°Ñ',
#  'Mighty',
#  'neobrutalist',
#  'goose-stepping',
#  'relieved',
#  'slated',
#  'less-prominent',
#  'nobody',
#  'Worth',
#  '312-662343',
#  'compulsive',
#  'self-guided',
#  'izi.Travel',
#  '//izi.travel/en/188d-bishkek-city-walking-tour/en',
#  'oZhirgal',
#  'BanyaSPA',
#  '312-486031',
#  'towel',
#  'noon-11pm',
#  '8am-11pm',
#  'sex-segregated',
#  'twin-cupped',
#  'wide-spread',
#  'nakedness',
#  'Manicures',
#  'massages',
#  'venik',
#  'oTUKTREKKING',
#  '101933',
#  '312-909115',
#  'www.tuk.kg',
#  'Joining',
#  'cross-section',
#  "B'Art",
#  'ContemporaryVOLUNTEERING',
#  '312-530092',
#  'www.bishkekart.kg',
#  'Karasaev',
#  'art-studio',
#  'Backpacker',
#  '//applehostel.kg',
#  'guest-accessible',
#  'ever-affable',
#  'Capsule',
#  '776-227789',
#  '556-227789',
#  '//hotelinkg.com',
#  'Billing',
#  'lockable',
#  'toiletries',
#  'Enter',
#  'Lotus',
#  '772-163240',
#  '708-060500',
#  'vivahostelkg',
#  '800-1000som',
#  'Second-floor',
#  'oBUGU',
#  'HotelDESIGN',
#  '312-892050',
#  '//buguhotel.kg',
#  'Umetaliev',
#  '60/70/120',
#  "'modern",
#  "'Scandinavian",
#  'oAsia',
#  'MountainsHOTEL',
#  'www.asiamountains-hotels.com',
#  '19-room',
#  'getaway',
#  'Sun-drenched',
#  'kitchen/sitting',
#  'help-yourself',
#  'co-owned',
#  'Mountains-2',
#  '312-540206',
#  '//asiamountains-hotels.com',
#  'Shoorukov',
#  '312-611911',
#  '//hostelkg.com',
#  '12/30',
#  '10-bed',
#  'InterHouseHOSTEL',
#  '312-323075',
#  'www.interhouse.kg',
#  '22/35',
#  'SayrakeBOUTIQUE',
#  '312-665843',
#  '708-705434',
#  'www.hotel-sayrake.com',
#  '70/120',
#  'villa-hotel',
#  'oligarch',
#  'wrought-iron',
#  'railings',
#  'super-comfortable',
#  'claw-foot',
#  'fittings',
#  'timber-clad',
#  'foliage',
#  'balcony-verandah',
#  '312-340000',
#  'www.grandhotel.kg/en',
#  'kitschy',
#  'nouveau-riche',
#  'comical',
#  'Urmat',
#  'OrdoHOTEL',
#  '312-311883',
#  '//urmatordo.kg',
#  'Isanova',
#  '50/60/70',
#  'functional',
#  'improvement',
#  'beige-brown',
#  'rentals',
#  'off-site',
#  'oSouthside',
#  '//southside.kg/',
#  'Suhomlin',
#  'shared/private',
#  '3000/3500som',
#  'styling',
#  'hectic',
#  '312-593312',
#  'www.bishkek-hotel.com',
#  'Kulatov',
#  '60/100/110',
#  'Smart',
#  'chocolate-and-cream',
#  'Vibrant',
#  'LodgeHOTEL',
#  '312-324889',
#  'www.silkroad.com.kg',
#  's/tw/d/ste',
#  '4000/5000/5500/6000som',
#  'Spread',
#  'kitchenette',
#  'Koyenkovoz',
#  "1B'Art",
#  'ContemporaryF2',
#  '2London',
#  'SchoolD2',
#  '3Asia',
#  'Mountains-2C2',
#  '4Bishkek',
#  '5Southside',
#  '6Dolce',
#  'VitaB4',
#  '7Sierra',
#  'RabatE2',
#  '8Kyrgyz',
#  'ConservatoryD4',
#  '9Alpinist',
#  'GearD2',
#  "10Book'IngemD2",
#  '11Gergert',
#  'SportB2',
#  '12Marco',
#  'PoloE2',
#  '13Tash',
#  'MallE2',
#  '14Afghan',
#  '15CBTE2',
#  '16EdelweissC2',
#  '17Tajikistan',
#  'EmbassyF3',
#  '18Avia',
#  'TrafficC2',
#  '19Pegasus',
#  'AirManasC4',
#  'Samsas',
#  '7-Day',
#  'Hypermarket',
#  '312-986100',
#  'www.gipermarket.kg',
#  'askhana',
#  'VostokaCENTRAL',
#  '312-436483',
#  '150-240som',
#  "'taste",
#  'Ð°Ð³Ð¼Ð°Ð½',
#  'Ð³Ñ€Ð¸Ð±Ð°Ð¼Ð¸',
#  'Ð¼ÑƒÑÑ€',
#  'OrdoCAFETERIA',
#  '707-999966',
#  '170/1',
#  '60-140som',
#  'tastiest',
#  'ÑÑ‚Ð¾Ð',
#  'Ð¾Ð²Ð°Ñ',
#  'Jalal-AbadCENTRAL',
#  '312-610083',
#  '80-160som',
#  'faceted',
#  'lattice-work',
#  'well-priced',
#  'Chicken',
#  'StarKOREAN',
#  '558-041111',
#  'www.chicken-star.com',
#  '190-275som',
#  'Fri-Sat',
#  '11am-11pm',
#  'Tue-Wed',
#  'kimbob',
#  'bingsoo',
#  'Chihoon',
#  'tango',
#  'Burger',
#  'HouseBURGERS',
#  '776-287437',
#  '//burgerhouse.kg',
#  '120-250som',
#  'Fast-casual',
#  'American-style',
#  "'Gamburger",
#  'Ak-BataCHINESE',
#  '312-681412',
#  '150-480som',
#  'oSupara',
#  'Ethno-ComplexKYRGYZ',
#  'INTERNATIONAL',
#  '312-465051',
#  'www.supara.kg',
#  'Karagul',
#  'Akmata',
#  ...]

# %% [markdown]
# long words of the text:

# %%
textset = set(text1)
long_words = [w for w in textset if len(w) > 15]
long_wo_urls = [w for w in long_words if not "www" in w]
long_wo_urls = [w for w in long_wo_urls if "-" in w]
print(sorted(long_wo_urls))
# Out:
# ["'historical-cultural", '//adventure-manufactory.com/en/tajik/tajik-home', '//aksu-jabagly.kz', '//ariahm.kz/projects/the-barley/', '//asiamountains-hotels.com', '//eco-park.kz/index_en.html', '//hostel-astana.hoteleastana.com/en/', '//hotel-rumi.business.site', '//imbeer.pizza-blues.kz/', '//izi.travel/en/188d-bishkek-city-walking-tour/en', '//khanshatyr.com/en/sky-beach-club', '//korean-house.kz', '//line-brew.kz/line-brew-almaty', '//line-brew.kz/line-brew-karaganda/', '//metelitsa-hotel.kz', '//parmigiano-group.com/en/restaurants/crudo', '//pass.rzd.ru/main-pass/public/en', '//pizza-blues.kz', '//seven-inn-boutique-hotel.hoteleastana.com', '//teplica.pizza-blues.kz', '//valentina-gh.narod.ru', '17Polvon-DarvozaB3', '18Polvon-DarvozaC4', '20Tosh-DarvozaB5', '21Tourism-OwadanD3', '24Samryk-KazynaD7', '28Taki-SarrafonA4', '2Dakhma-i-ShokhonF1', '30Taki-ZargaronE2', '3rd-class/2nd-class', '4Historical-Cultural-Ethnographic', '5Maghok-i-AttarE2', '6Bogcha-DarvozaC1', 'ACommunity-based', 'ACurrency-exchange', 'Adventure-minded', 'Alexandria-Eskhate', 'Alexandria-Oxiana', 'Australian-owned', 'Ayaz-QalaFORTRESS', 'Bukhoro-i-sharif', 'Chagano-naberezhnaya', 'Cholpon-Atinskaya', 'Community-tourism', 'Dakhma-i-Shokhon', 'Earthquake-formed', 'English-language', 'English-speaking', 'English/non-English', 'Ethno-ComplexKYRGYZ', 'French-sponsored', 'Gorno-Badakhshan', 'Governor-General', 'Hauz-i-SanginMOSQUE', 'Historical-Cultural-Ethnographic', 'Ichon-QalaHISTORIC', 'International-standard', 'Irtysh-Karaganda', 'Ishkashim-Khorog', 'Islamic-oriented', 'Jalal-AbadCENTRAL', 'Karakhanid-style', 'Kazakh-dominated', 'Kazakh-populated', 'Kazakhstan-based', 'Kochkor-specific', 'Konye-Urgenchâ€™s', 'Kyrgyz/Russian-speaking', 'Kyrgyzstan-based', 'Leninabad-oriented', 'Long-established', 'Marv-i-shahjahan', 'Michelin-starred', 'Migration-police', 'Mountain-tourism', 'Nazarbayev-centric', 'Nevada-Semipalatinsk', 'Non-prescription', 'Nuratau-Kyzylkum', 'Oscar-shortlisted', 'Passenger-carrying', 'Persepolis-inspired', 'Persian-speaking', 'Pushkin-inspired', 'Russian-country-mansion', 'Russian-designed', 'Russian-influenced', 'Russian-language', 'Russian-speaking', 'Samarkand-Bukhara', 'Semi-Underground', 'Shahr-e-kuhnaOLD', 'Shakhtinsk-bound', 'Shamanic-Buddhist', 'Stalinist-neoclassical', 'Tarikhi-Madeni-Etnografiyalyk', 'Uchkurgon/Shamaldy-Say', 'Unesco-affiliated', 'Unesco-recognised', 'Unesco-sponsored', 'Ust-Kamenogorsk-based', 'Ust-KamenogorskC1', 'Ust-KamenogorskHOTEL', 'Ust-Kamenogorskâ€™s', 'Uzbekistan-based', 'Volkswagen-sized', 'Zapadno-Altaysky', 'Zoroastrian-inspired', 'Zorostrian-inspired', 'above-the-treeline', 'adventure-seeking', 'adventure-sports', 'adventure-sports-related', 'adventure-travel', 'air-conditioning', 'al-TermiziMAUSOLEUM', 'alternative-lifestyle', 'altitude-related', 'animal-festooned', 'anti-inflammatory', 'apartment-hostels', 'arabesque-styled', 'back-of-the-truck', 'backpacker-oriented', 'backpacker-style', 'balcony-verandah', 'bare-brick-walled', 'biological-weapons', 'blue-glass-and-white-marble', 'bourgeoisie-nationalist', 'brown-bear-spotting', 'business-oriented', 'caffeine-and-strudel', 'carnivore-enticing', 'chaikhana-restaurant', 'chamber-orchestra', 'chessboard-clutching', 'chocolate-and-cream', 'circle-patterned', 'climate-friendly', 'cockroach-infested', 'comfortable-enough', 'communist-dominated', 'community-based-tourism', 'community-tourism', 'community-tourism-affiliated', 'company-specific', 'consciousness-raising', 'conservatory-like', 'consular-section', 'contemporary-art', 'contemporary-arts', 'continent-spanning', 'counter-revolutionary', 'country-specific', 'debit-/credit-card', 'demented-looking', 'difficult-to-impossible', 'difficult-to-pronounce', 'do-it-yourselfers', 'down-on-his-luck', 'early-20th-century', 'earthquake-prone', 'earthquake-proofing', 'earthquake-triggered', 'end-of-the-world', 'energy-efficient', 'environment-protection', 'ex-son-in-law-turned-political-enemy', 'expatriate ...

# %% [markdown]
# Let's return to our task of finding words that characterize a text. Notice that the long words in text4 reflect its national focus — constitutionally, transcontinental — whereas those in text5 reflect its informal content: boooooooooooglyyyyyy and yuuuuuuuuuuuummmmmmmmmmmm. Have we succeeded in automatically extracting words that typify a text? Well, these very long words are often hapaxes (i.e., unique) and perhaps it would be better to find frequently occurring long words. This seems promising since it eliminates frequent short words (e.g., the) and infrequent long words (e.g. antiphilosophists). Here are all words from the corpus that are longer than seven characters, that occur more than seven times:

# %%
fdist_new = FreqDist(text1)
characterizing_words = sorted(w for w in set(text1) if len(w) > 7 and fdist_new[w] > 15)
print(characterizing_words)
# Out:
# ['19th-century', '2Activities', '3Entertainment', '4Sleeping', '6Drinking', '7Shopping', '8Getting', '8Information', 'Activities', 'Afghanistan', 'Airlines', 'Aksu-Zhabagyly', 'Ala-Archa', 'Alexander', 'Alternatively', 'Although', 'Altyn-Emel', 'Amu-Darya', 'Arslanbob', 'Ashgabat', 'Asiaâ€™s', 'Avtovokzal', 'Azerbaijan', 'Badakhshan', 'BarskoÃ¶n', 'Bokonbaevo', 'Bolsheviks', 'Buddhist', 'Chimbulak', 'Chinggis', 'Cholpon-Ata', 'Dashoguz', 'December', 'Destination', 'Dushanbe', 'Embassies', 'English-speaking', 'European', 'Festival', 'Furmanov', 'Georgian', 'Guesthouse', 'Highlights', 'Homestay', 'HotelHOTEL', 'Ichon-Qala', 'Independence', 'Information', 'International', 'Irkeshtam', 'Iskander-Kul', 'Issyk-KÃ¶l', 'Jalal-Abad', 'Jeti-Ã–gÃ¼z', 'Jyrgalan', 'Karaganda', 'Karakalpakstan', 'Kazakhstan', 'Kazakhstanâ€™s', 'Kazarman', 'Konye-Urgench', 'Korgalzhyn', 'Kyrgyzstan', 'Kyzylorda', 'Lyabi-Hauz', 'Mangistau', 'Margilon', 'Marshrutka', 'Marshrutkas', 'MasterCard', 'Mausoleum', 'Medressa', 'Mikrorayon', 'Minibuses', 'Ministry', 'Mohammed', 'Mountains', 'MuseumMUSEUM', 'National', 'Nazarbayev', 'Nightlife', 'Northern', 'November', 'Penjikent', 'President', 'Regional', 'Registan', 'Registration', 'Republic', 'Russians', 'Samarkand', 'Sary-Chelek', 'Sary-Mogol', 'Sary-Tash', 'Saturday', 'Semipalatinsk', 'September', 'Shakhrisabz', 'Shymkent', 'Son-KÃ¶l', 'Southern', 'Soviet-era', 'Suusamyr', 'Syr-Darya', 'Tajikistan', 'Tamerlane', 'Tashkent', 'Tashkentâ€™s', 'Thursday', 'Timurâ€™s', 'Toktogul', 'Torugart', 'Toshkent', 'Transoxiana', 'Transport', 'Travellers', 'Trekking', 'Turkestan', 'Turkmenabat', 'Turkmenbashi', 'Turkmenistan', 'Understand', 'Ust-Kamenogorsk', 'Uzbekistan', 'Uzbekistanâ€™s', 'Zerafshan', 'accepted', 'accessible', 'accommodation', 'according', 'activities', 'actually', 'addition', 'admission', 'advances', 'afternoon', 'agencies', 'airlines', 'alternative', 'although', 'altitude', 'anything', 'anywhere', 'apartment', 'application', 'archaeological', 'architectural', 'architecture', 'arranged', 'arriving', 'artefacts', 'atmosphere', 'atmospheric', 'attractions', 'attractive', 'authentic', 'available', 'backdrop', 'bathroom', 'bathrooms', 'beautiful', 'bookings', 'breakfast', 'building', 'buildings', 'business', 'capitals', 'celebrated', 'centuries', 'certainly', 'charming', 'children', 'citizens', 'climbing', 'clothing', 'collection', 'colourful', 'comfortable', 'commission', 'communities', 'community', 'companies', 'complete', 'concerts', 'conditions', 'connections', 'consider', 'considered', 'consulate', 'contains', 'continue', 'continued', 'continues', 'convenient', 'converted', 'countries', 'courtyard', 'crossing', 'crossings', 'cultural', 'currency', 'currently', 'decorated', 'delicious', 'departure', 'departures', 'depending', 'designed', 'destination', 'destinations', 'destroyed', 'development', 'different', 'difficult', 'directly', 'disaster', 'displays', 'distance', 'domestic', 'dramatic', 'dumplings', 'earthquake', 'economic', 'electricity', 'elsewhere', 'embassies', 'embroidery', 'enormous', 'entering', 'entirely', 'entrance', 'equipment', 'especially', 'espresso', 'essential', 'established', 'eventually', 'everything', 'everywhere', 'excellent', 'exchange', 'excursions', 'exhibits', 'expected', 'expensive', 'experience', 'experienced', 'exploring', 'extensive', 'facilities', 'families', 'fantastic', 'fascinating', 'favourite', 'favourites', 'features', 'festival', 'followed', 'following', 'foreigners', 'formerly', 'fortress', 'frequent', 'friendly', 'generally', 'glaciers', 'glorious', 'gmail.com', 'government', 'greatest', 'guesthouse', 'guesthouses', 'h10am-10pm', 'h10am-6pm', 'h11am-midnight', 'h8am-5pm', 'h8am-6pm', 'h8am-7pm', 'h8am-8pm', 'h9am-11pm', 'h9am-1pm', 'h9am-5pm', 'h9am-6pm', 'h9am-7pm', 'h9am-8pm', 'h9am-noon', 'high-altitude', 'highlight', 'historic', 'historical', 'hnoon-midnight', 'holidays', 'homestay', 'homestays', 'horseback', 'hospitality', 'important', 'impressive', 'included', 'i ...

# %% [markdown]
# A collocation is a sequence of words that occur together unusually often. Thus red wine is a collocation, whereas the wine is not. A characteristic of collocations is that they are resistant to substitution with words that have similar senses; for example, maroon wine sounds definitely odd.
#
# To get a handle on collocations, we start off by extracting from a text a list of word pairs, also known as bigrams. This is easily accomplished with the function bigrams(): ...
#
# Now, collocations are essentially just frequent bigrams, except that we want to pay more attention to the cases that involve rare words. In particular, we want to find bigrams that occur more often than we would expect based on the frequency of the individual words. The  collocations() function does this for us. We will see how it works later.
#
# The collocations that emerge are very specific to the genre of the texts. In order to find red wine as a collocation, we would need to process a much larger body of text.

# %%
a = text1.collocations()
# Out:
# GOOGLE MAP; MAP GOOGLE; Central Asia; Silk Road; Central Asian; per
# person; incl breakfast; bus station; train station; shared taxis;
# Shared taxis; National Park; Fergana Valley; Aral Sea; shared taxi;
# per day; Pamir Hwy; Nature Reserve; Fan Mountains; Bus Station
