# %%
with open('centralasia.txt', errors="ignore") as file:
    file_contents = file.read()

with open('moe.txt', errors="ignore") as file:
    moe_txt = file.read()

# %%
from nltk import *

file_in_words = word_tokenize(file_contents)
text1 = Text(file_in_words)

moe_words = word_tokenize(moe_txt)
moe = Text(moe_words)

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words("german"))

filtered_moe=[]
for w in moe_words:
    if len(w) <= 4:
        continue
    if w not in stop_words:
        filtered_moe.append(w)

fdist = FreqDist(filtered_moe)
print(fdist)
print(fdist.most_common(50))
# Out:
# <FreqDist with 51960 samples and 267003 outcomes>
# [('Ulrich', 2891), ('schon', 1409), ('Menschen', 1151), ('Agathe', 1095), ('immer', 1034), ('sagte', 974), ('sagen', 794), ('Clarisse', 783), ('hätte', 740), ('Leben', 721), ('wurde', 707), ('Diotima', 690), ('Arnheim', 667), ('Gefühl', 658), ('konnte', 639), ('Augenblick', 629), ('Walter', 603), ('Mensch', 584), ('Liebe', 547), ('fühlte', 539), ('vielleicht', 526), ('Gedanken', 521), ('heute', 518), ('davon', 510), ('fragte', 506), ('dachte', 491), ('wenig', 481), ('gerade', 474), ('großen', 471), ('gesagt', 454), ('lassen', 447), ('denen', 445), ('Weise', 444), ('wirklich', 431), ('Augen', 430), ('wußte', 414), ('worden', 413), ('daran', 410), ('dabei', 393), ('Gesicht', 389), ('Geist', 379), ('natürlich', 378), ('eigentlich', 378), ('mußte', 376), ('Stumm', 374), ('sogar', 367), ('Zustand', 367), ('recht', 364), ('große', 355), ('plötzlich', 347)]

# %% [markdown]
# 4.

# %%
sorted(w for w in set(text1) if w.endswith("ness"))
# Out:
# ['Business',
#  'Coolness',
#  'Fairness',
#  'Neighbourliness',
#  'Sickness',
#  'adroitness',
#  'blandness',
#  'bleakness',
#  'business',
#  'completeness',
#  'consciousness',
#  'darkness',
#  'discount/standard/business',
#  'dizziness',
#  'drowsiness',
#  'economy/business',
#  'emptiness',
#  'firmness',
#  'fitness',
#  'foreigner-friendliness',
#  'frankness',
#  'happiness',
#  'heavy-handedness',
#  'honest-to-goodness',
#  'hopelessness',
#  'illness',
#  'kindness',
#  'lightness',
#  'nakedness',
#  'numbness',
#  'oddness',
#  'openness',
#  'ornateness',
#  'remoteness',
#  'richness',
#  'road-readiness',
#  'ruthlessness',
#  'selflessness',
#  'sickness',
#  'thickness',
#  'tiredness',
#  'uniqueness',
#  'wilderness',
#  'witness',
#  'worldliness',
#  'worthlessness',
#  'â€˜business']

# %%
sorted(w for w in set(text1) if w.istitle()) # if it contains capital-letters
# Out:
# ["'3P",
#  "'A",
#  "'Afrosiyab",
#  "'After",
#  "'Almaty",
#  "'Altai",
#  "'Andijon",
#  "'Atlas",
#  "'Beans",
#  "'Beijing",
#  "'Book",
#  "'Bozor",
#  "'Bukhara",
#  "'Castles",
#  "'Celestial",
#  "'Central",
#  "'Democratic",
#  "'Development'",
#  "'Devil",
#  "'Disneyfication",
#  "'Drop",
#  "'Eggy",
#  "'Face",
#  "'Father",
#  "'Forty",
#  "'Frunze",
#  "'Future",
#  "'Gamburger",
#  "'Gasman",
#  "'God",
#  "'Golden",
#  "'Grave",
#  "'Great",
#  "'Green",
#  "'Hall",
#  "'Hospitality",
#  "'I",
#  "'Imagine",
#  "'In",
#  "'Kara-Kyrgyzâ€™",
#  "'Kyzylkala",
#  "'Land",
#  "'Leader",
#  "'Little",
#  "'M",
#  "'Manas",
#  "'Marco",
#  "'Masterpieces",
#  "'Melodies",
#  "'Mezhdunarodnaya",
#  "'Mother",
#  "'Movement",
#  "'Muddy",
#  "'New",
#  "'No",
#  "'Nomad",
#  "'North",
#  "'Northern",
#  "'Old",
#  "'One",
#  "'Onion",
#  "'Party",
#  "'Penjikent",
#  "'People",
#  "'Pitak",
#  "'Pompeii",
#  "'President",
#  "'Queen",
#  "'Rahmon",
#  "'Ratsek",
#  "'Reasonable",
#  "'Rock",
#  "'Roof",
#  "'S",
#  "'Sary-Tologoy",
#  "'Scandinavian",
#  "'Sharq",
#  "'Shoro",
#  "'Silk",
#  "'Singapore",
#  "'Snow",
#  "'Soviet",
#  "'Stan",
#  "'Stans",
#  "'Stary",
#  "'Tajik",
#  "'Temir",
#  "'The",
#  "'There",
#  "'They",
#  "'Toilet",
#  "'Tournament",
#  "'Traveller",
#  "'Treasure",
#  "'Tsar",
#  "'Turkmenised",
#  "'Turksib",
#  "'Ukrainian",
#  "'Uralsk",
#  "'Ust",
#  "'Valley",
#  "'War",
#  "'Western",
#  "'What",
#  "'When",
#  "'Without",
#  "'Xinjiang",
#  "'Yagnob",
#  "'Zij",
#  "'Ð–",
#  '-11Â°C',
#  '-20Â°C',
#  '-22Â°C',
#  '-30Â°C',
#  '-45Â°C',
#  '-49Â°F',
#  '-4Â°F',
#  '0.3M',
#  '0.5L',
#  '054B',
#  '10,000-12,000T',
#  '10,000-15,000S',
#  '10,000-16,000S',
#  '10,000-17,000S',
#  '10,000-20,000S',
#  '10,000-23,000S',
#  '10,000-25,000S',
#  '10,000-26,000S',
#  '10,000-30,000S',
#  '10,000-40,000S',
#  '10,000/14,000T',
#  '10,000/16,000/21,000T',
#  '10,000/25,000/8000S',
#  '10,000/3000S',
#  '10,000/6000/15,000S',
#  '10,000/6000T',
#  '10,000/7000S',
#  '10,000S',
#  '10,000T',
#  '10,00S',
#  '10,492T',
#  '10,500/19,000T',
#  '10,500S/15,000S',
#  '10,500T',
#  '10,520T',
#  '10,600T',
#  '10,880S',
#  '100,000S',
#  '100,000T',
#  '100/250/500T',
#  '1000-1800T',
#  '1000-2400T',
#  '1000/2000T',
#  '1000S',
#  '1000T',
#  '100Informal',
#  '100T',
#  '101,000/150,000S',
#  '101B',
#  '101Marshrutka',
#  '1027T',
#  '102Marshrutka',
#  '103Marshrutka',
#  '104A',
#  '104S7E4',
#  '104Â°F',
#  '105Turkish',
#  '106,000/158,000S',
#  '106Uzbekistan',
#  '1070T',
#  '107Velo',
#  '109A',
#  '109Western',
#  '10A',
#  '10Afghan',
#  '10Altyn',
#  '10Asaka',
#  '10Bazaar',
#  '10Chashma',
#  '10Grand',
#  '10History',
#  '10Hotel',
#  '10Hovrenko',
#  '10Interhouse',
#  '10Islom',
#  '10Kafe',
#  '10Line',
#  '10M',
#  '10Marifat',
#  '10Marshrutka',
#  '10Mosque',
#  '10National',
#  '10Rabat',
#  '10Shiny',
#  '10Statue',
#  '10Stone',
#  '10T',
#  '10Tomb',
#  '10U',
#  '10Â½',
#  '10Â½-17Â¼',
#  '11,000-15,000T',
#  '11,000/13,000T',
#  '11,000/16,200T',
#  '11,572T',
#  '11,595/7435T',
#  '11.40M',
#  '110,000/159,000S',
#  '1100-3300T',
#  '1100-3400T',
#  '1100-4600T',
#  '110T',
#  '116,000T',
#  '116A',
#  '117A',
#  '11A',
#  '11Badakhshan',
#  '11Emerald',
#  '11Fayzulla',
#  '11Gergert',
#  '11Hotel',
#  '11House',
#  '11Imon',
#  '11Interhouse',
#  '11Islom',
#  '11Main',
#  '11Mosque',
#  '11National',
#  '11Palace',
#  '11Panfilov',
#  '11Ribeye',
#  '11Shared',
#  '11Statue',
#  '11Uzbekistan',
#  '11Victory',
#  '11Zimbardor',
#  '11Zubr',
#  '11Â½',
#  '12,000-30,000S',
#  '12,000/15,000T',
#  '12,000/5000S',
#  '12,000S',
#  '12,000T',
#  '12,213T',
#  '12,462T',
#  '12,500T',
#  '120,000S',
#  '1200-2200T',
#  '1200-3400T',
#  '1200-3900T',
#  '1200S',
#  '1200T',
#  '120M/480M',
#  '124A',
#  '1265/1140S',
#  '1270S',
#  '12A',
#  '12Ayan',
#  '12Ayyal',
#  '12Chalet',
#  '12Coffee',
#  '12Gaukushan',
#  '12Hazrat',
#  '12Hotel',
#  '12Istiklol',
#  '12Jamilya',
#  '12Juma',
#  '12Kuba',
#  '12L',
#  '12Makhdumi',
#  '12Marco',
#  '12Nomad',
#  '12Palace',
#  '12Pizza',
#  '12Presidential',
#  '12Shared',
#  '12Shashlyki',
#  '12Suleiman',
#  '12White',
#  '12Â¼-14Â¼',
#  '12Â½',
#  '12Â¾-15Â¼',
#  '13,000-20,000S',
#  '13,000-30,000S',
#  '13,000/16,000T',
#  '13,071T',
#  '13,333T',
#  '13,520/16,400T',
#  '13,567/9774/4443T***',
#  '13,567T',
#  '13,900/8556T',
#  '130,000S',
#  '1300-2700T',
#  '1300-2800T',
#  '1300T',
#  '130B',
#  '1340-3480T',
#  '13Cafe',
#  '13Guns',
#  '13Hoja',
#  '13Hotel',
#  '13House',
#  '13Juma',
#  '13Kullalik',
#  '13Kyrgyz',
#  '13Local',
#  '13Mausoleum',
#  '13Pamir',
#  '13Respublika',
#  '13Suleiman',
#  '13Tash',
#  '13Tau',
#  '13Â½',
#  '13Â½-21',
#  '13Â¾',
#  '14,000-16,000S',
#  '14,000-22,000S',
#  '14,000-30,000S',
#  '14,000-45,000S',
#  '14,000S',
#  '14,000T',
#  '14,157T',
#  '14,300S',
#  '1400-5300T',
#  '1400T',
#  '140A',
#  '1426T',
#  '1450T',
#  '147,000T',
#  '148B',
#  '14Afghan',
#  '14Hoja',
#  '14House',
#  '14Iceberg',
#  '14Kaldirgochbiy',
#  '14Karaganda',
#  '14Karakol',
#  '14Kuhna',
#  '14Long-Distance',
#  '14Mega',
#  '14Mubarak',
#  '14Naryn',
#  '14Rohatbahsh',
#  '14Rudaki',
#  '14Sova',
#  '14Three-Storey',
#  '14Zhirgal',
#  '14Â½',
#  '14Â¾',
#  '15,000-19,000S',
#  '15,000-20,000S',
#  '15,000-20000S',
#  '15,000-23,000S',
#  '15,000-25,000S',
#  '15,000-30,000S',
#  '15,000-35,000T',
#  '15,000/18,000T',
#  '15,000/3000/14,000S',
#  '15,000/3000/21,000S',
#  '15,000/6500T',
#  '15,000S',
#  '15,000T',
#  '15,086T',
#  '15,200/18,000T',
#  '150,000S',
#  '1500-2800T',
#  '1500-3200T',
#  '1500/2500T',
#  '1500/3000S',
#  '1500/3000T',
#  '1500/3500S',
#  '1500/700T',
#  '1500S',
#  '1500T',
#  '150T',
#  '1553T',
#  '15A',
#  '15Afghan',
#  '15Aiyl',
#  '15Asaka',
#  '15Asia',
#  '15Free',
#  '15Imperia',
#  '15Ismail',
#  '15Kazak',
#  '15Kopet',
#  '15Kulkedash',
#  '15Kutlug',
#  '15M',
#  '15Main',
#  '15Migration',
#  '15Minivans',
#  '15Qoraboy',
#  '15Shah',
#  '15T',
#  '15Teskey',
#  '15Zenkov',
#  '15Â½-17Â¾',
#  '15Â¾',
#  '16,000/17,000T',
#  '16,000S',
#  '16,000T',
#  '16,000T/30,000/75,000T',
#  '1600-3600T',
#  '1600T',
#  '1650-6800T',
#  '168A',
#  '16A',
#  '16Altyn',
#  '16Bus',
#  '16Eco',
#  '16German',
#  '16Jewish',
#  '16Minor',
#  '16Mohammed',
#  '16National',
#  '16Regional',
#  '16Shared',
#  '16Tajik',
#  '16Taxis',
#  '16Tulpar',
#  '16Zhibek',
#  '16Â¾',
#  '16Â¾-19Â¾',
#  '17,000/23,000T',
#  '1700-2800T',
#  '1700T',
#  '170A',
#  '179A',
#  '17Arasan',
#  '17Capsule',
#  '17Jewish',
#  '17Kubat',
#  '17Maatova',
#  '17Miras',
#  '17Mongolian',
#  '17Moyie',
#  '17Paromnaya',
#  '17Rukhobod',
#  '17Shared',
#  '17Tajikistan',
#  '17Transport',
#  '17Victory',
#  '17Yak',
#  '17Â¼',
#  '18,000-28,000T',
#  '18,000/22,000T',
#  '18,000S',
#  '18,000T',
#  '18,065T',
#  '18,300/22,500T',
#  '18,335/11,496T',
#  '18,810/22,657T',
#  '1800-2900T',
#  '1800-3500T',
#  '1800-3700T',
#  '1800-7000T',
#  '1800-9900T',
#  '1800/3800T',
#  '1800T',
#  '180T',
#  '187A',
#  '1898T',
#  '18Avia',
#  '18Central',
#  '18Kukeldash',
#  '18Museum',
#  '18Osh',
#  '18Russian',
#  '18Sher',
#  '18Tajik',
#  '18World',
#  '19,000S',
#  '19,000T',
#  '19,082/14,938T**',
#  '19,467T',
#  '19,980T',
#  '1900-3400T',
#  '1900-6900T',
#  '19A',
#  '19Bus',
#  '19Caravan',
#  '19Grand',
#  '19Kan',
#  '19National',
#  '19Navoi',
#  '19Pegasus',
#  '19Sayid',
#  '19Statue',
#  '19Tekke',
#  '19Valentina',
#  '19Writers',
#  '19Â¼',
#  '19Â½',
#  '19Â¾',
#  '1A',
#  '1Afghan',
#  '1Ak-Saray',
#  '1Alexander',
#  '1Art',
#  '1Azadi',
#  '1B',
#  "1B'Art",
#  '1B2',
#  '1Bayterek',
#  '1Bibi-Khanym',
#  '1Buddhist',
#  '1Central',
#  '1Chorsu',
#  '1Dom',
#  '1Dungan',
#  '1Ethnography',
#  '1Fergana',
#  '1Former',
#  '1Hiking',
#  '1Kalta',
#  '1Khan',
#  '1Lenin',
#  '1M',
#  '1Museum',
#  '1Ozero',
#  '1Regional',
#  '1Savitsky',
#  '1Sights',
#  '1State',
#  '1T',
#  '1Top',
#  '1Yasaui',
#  '1Â¼',
#  '1Â½',
#  '1Â¾',
#  '2-2Â½',
#  '2.54M',
#  '2.73M',
#  '2.80M',
#  '20,000-28,000S',
#  '20,000-30,000S',
#  '20,000/35,000S',
#  '20,000S',
#  '20,000T',
#  '20,122/14,703T**',
#  '20,700T',
#  '200,000S',
#  '200-300T',
#  '200-600T',
#  '2000/8000S',
#  '2000S',
#  '2000T',
#  '200T',
#  '2025T',
#  '2088T',
#  '20Hotel',
#  '20M',
#  '20Northern',
#  '20Oliy',
#  '20Silk',
#  '20Taxi',
#  '20Tilla-Kari',
#  '20Â¼',
#  '20Â½',
#  '21,700T',
#  '2158/1424T',
#  '21Alymbek',
#  '21Hotel',
#  '21Kochevnik',
#  '21Modari',
#  '21Nur',
#  '21Railway',
#  '21Ulugbek',
#  '22,000-47,000S',
#  '22,000/20,000S',
#  '22,000/24,000T',
#  '22,000/5000S',
#  '22,000T',
#  '22,800T',
#  '22,900T',
#  '22,950/27,200T',
#  '2200-5000T',
#  '2200/600T',
#  '2200T',
#  '220A',
#  '220V',
#  '22A',
#  '22Hammomi',
#  '22Hotel',
#  '22Islambek',
#  '22Lotus',
#  '22Lovely',
#  '22Nadir',
#  '22Palace',
#  '22Romanov',
#  '22Uzbek',
#  '22Â¼',
#  '22Â½',
#  '2397T',
#  '23A',
#  '23Arkanchi',
#  '23Fat',
#  '23Hotel',
#  '23Nadir',
#  '23Ploshchad',
#  '23Senate',
#  '23Silk',
#  '23Sogda',
#  '23Walking',
#  '23Â¼',
#  '23Â¾-25Â¾',
#  '24,000/40,000T',
#  '24,000S',
#  '24,000T',
#  '24,352T',
#  '24-110M',
#  '2422T',
#  '247A',
#  '249T',
#  '24Almaty',
#  '24Green',
#  '24Guest',
#  '24Hotel',
#  '24Old',
#  '24Sheikh',
#  '24Urmat',
#  '24Â¾',
#  '25,000-38,000S',
#  '25,000-43,000S',
#  '25,000-60,000S',
#  '25,000-80,000S',
#  '25,000/50,000T',
#  '25,000S',
#  '25,000T',
#  '25-50M',
#  '250,000S',
#  '250/1000T',
#  '2500-5000T',
#  '2500-5200T',
#  '2500/1500T',
#  '2500/6500/8000T',
#  '2500S',
#  '2500T',
#  '250T',
#  '2540-4980T',
#  '2588T',
#  '259A',
#  '25Bahodir',
#  '25Grand',
#  '25Hotel',
#  '25Karakol',
#  '25Lotte',
#  '25Osh',
#  '25Photo',
#  '25Sheikhantaur',
#  '25Viva',
#  '25Â¾',
#  '26,000S',
#  '26,500T',
#  '266T',
#  '267,000/390,000S',
#  '267T',
#  '26A',
#  '26Antique',
#  '26Bibi',
#  '26Hotel',
#  '26Makhbuba',
#  '26Puppet',
#  '26Shabyt',
#  '26State',
#  '26Tsarskii',
#  '27,000T',
#  '27,100/18,021T**',
#  '27,600T',
#  '2700-12,000T',
#  '2700/4700T',
#  '2750T',
#  '27Burger',
#  '27Emir',
#  '27Hotel',
#  '27Marian',
#  '27State',
#  '27Transport',
#  '27Â¼',
#  '27Â¼-31Â½',
#  '28,000/36,000/68,000T',
#  '28,000T',
#  '28,200T',
#  '28,370/21,695T**',
#  '28,500T',
#  '2800-6500T',
#  '2800T',
#  '28A',
#  '28Astana',
#  '28Chaikana',
#  '28Hotel',
#  '28Kork',
#  '28Meros',
#  '28Serena',
#  '28Statue',
#  '28Â½',
#  '29,600T',
#  '29A',
#  '29Apple',
#  '29Chaikhana',
#  '29Hotel',
#  '29Kyrgyz',
#  '29R',
#  '29Taki-Telpak',
#  '29Wedding',
#  '29Zebo',
#  '29Â½',
#  '29Â½-34',
#  '2A',
#  '2Abay',
#  '2Activities',
#  '2Ala-Too',
#  '2Alisher',
#  '2Alleya',
#  '2Amir',
#  '2B3',
#  '2Carpet',
#  '2Char',
#  '2Coal',
#  '2D3',
#  '2Ethnography',
#  '2Fine',
#  '2Freedom',
#  '2Friday',
#  '2Great',
#  '2Holy',
#  '2Ile-Alatau',
#  '2Independence',
#  '2Karakalpak',
#  '2Kazakh',
#  '2Khan',
#  '2Khorog',
#  '2Loik',
#  '2London',
#  '2M',
#  '2Museum',
#  '2Pahlavon',
#  '2Panchshanbe',
#  '2Regional',
#  '2Roof',
#  '2Rudaki',
#  '2Rukh',
#  '2T',
#  '2Termiz',
#  '2Watching',
#  '2Â¼',
#  '2Â½',
#  '2Â¾',
#  '2Â¾-3Â¾',
#  '3.16M',
#  '3.45M',
#  '3.50M',
#  '3.5M',
#  '3.98M',
#  '30,000-45,000T',
#  '30,000S',
#  '30,000T',
#  '30,700T',
#  '30,900T',
#  '300-2000T',
#  '300-600T',
#  '3000-3750T',
#  '3000-7000T',
#  '3000/10,000T',
#  '3000/2000/2000T',
#  '3000S',
#  '3000T',
#  '300T',
#  '3015T',
#  '3032T',
#  '304T',
#  '3053T',
#  '30A',
#  '30Belon-Land',
#  '30Chicken',
#  '30Hotel',
#  '30Mirzoboshi',
#  '30Osh',
#  '30T',
#  '30Â°',
#  '30Â¾',
#  '3189T',
#  '31Asia',
#  '31Hostel',
#  '31Hotel',
#  '31Lessor',
#  '31M',
#  '31Otabek',
#  '31Saimalu',
#  '31Turki',
#  '32,400/34,600T',
#  '3200/6800/8300T',
#  '32Asian',
#  '32Bir',
#  '32Chaykhona',
#  '32Extreme',
#  '32Frunze',
#  '32Hotel',
#  '32Jahongir',
#  '32Nomad',
#  '32Ulugbek',
#  '3300/6200/9150T',
#  '3350-19,950T',
#  '3350T',
#  '335T',
#  '33A',
#  '33Art',
#  '33Cafe',
#  '33Destination',
#  '33Hotel',
#  '33Kyrgyz',
#  '33Rahat',
#  '3400T',
#  '3483T',
#  '34Art',
#  '34B',
#  '34Hammom',
#  '34Kheivak',
#  '34Kyrgyz',
#  '34Nomad',
#  '34Registon',
#  '34Rixos',
#  '35,000S',
#  '35,000T',
#  '35,400T',
#  '35,650T',
#  '350/1500T',
#  '350/150T',
#  '350/600T',
#  '3500-4000T',
#  '3500/10,454T',
#  '3500/14,369T',
#  '3500/2000T',
#  '3500/3800T',
#  '3500T',
#  '350T',
#  '3579T',
#  '35Grand',
#  '35Hammon',
#  '35Khorezm',
#  '35Marco',
#  '35Otyrar',
#  '35Sky',
#  '35Timur',
#  '35Turkestan',
#  '35Â°C',
#  '36,500T',
#  '36A',
#  '36Amelia',
#  '36Art',
#  '36Grand',
#  '36Mirzobashi',
#  '36Morning',
#  '36Munduz',
#  '36Plov',
#  '36Seven',
#  '36Visit',
#  '36Â°C',
#  '37,000/56,000S',
#  '37,000T',
#  '37,200T',
#  '37Amulet',
#  '37Besh',
#  '37Gulnara',
#  '37Main',
#  '37Old',
#  '37Oshi',
#  '37Terasse',
#  '38,000/120,000/40,000S',
#  '3800T',
#  '383,000/577,000S',
#  '38Arabon',
#  '38Astana',
#  '38B',
#  '38Cafe',
#  '38Hotel',
#  '38Marshrutka',
#  '38Poitakht',
#  '38Shared',
#  '38Tokhir-Zukhra',
#  '3900T',
#  '398T',
#  '39Cafe',
#  '39Dastarkhan',
#  '39Emir',
#  '39Hotel',
#  '39Khiva',
#  '39Marshrutka',
#  '39Puppet',
#  '39Ural',
#  '39Â¾',
#  '3A',
#  '3Aliman',
#  '3Altyn',
#  '3Anatomical',
#  '3Art',
#  '3Asia',
#  '3Birds',
#  '3Bishkek',
#  '3D',
#  '3Entertainment',
#  '3Ethnography',
#  '3G',
#  '3Hilvet',
#  '3Historical',
#  '3Hojibek',
#  '3Horse',
#  '3Hotel',
#  '3Ice',
#  '3Independence',
#  '3Jayma',
#  '3Jipek',
#  '3Kalon',
#  '3Karaganda',
#  '3Karakol',
#  '3Kazakhstan',
#  '3Kruiz',
#  '3M',
#  '3Museum',
#  '3Olim',
#  '3Regional',
#  '3Sharq',
#  '3Statue',
#  '3Tosh-Hovli',
#  '3World',
#  '3Yubileyny',
#  '3Â¼',
#  '3Â½',
#  '3Â½-4Â¼',
#  '3Â½-5Â½',
#  '3Â½-7Â½',
#  '3Â¾',
#  '4.52M',
#  '40,000-50,000S',
#  '40,000S',
#  '40,000T',
#  '40,500T',
#  '400,000S',
#  '400-900T',
#  '400/200T',
#  '4000/3000S',
#  '4000/6000T',
#  '4000/7000T',
#  '4000S',
#  '4000T',
#  '400T',
#  '40A',
#  '40Hotel',
#  '40Kyzyl',
#  '40M',
#  '40Marshrutka',
#  '40Sary',
#  '40Tourist',
#  '40Vkys',
#  '40Â°C',
#  '40Â½',
#  '40Â¾',
#  '41,000S',
#  '41/A',
#  '41A',
#  '41Eagilik',
#  '41Hotel',
#  '41Hovli',
#  '41Marshrutka',
#  '41Old',
#  '41Shared',
#  '41Taj',
#  '42,000/57,000/74,000S',
#  '42,000/57,000S',
#  '42,000/64,000S',
#  '4200T',
#  '42Hyatt',
#  '42Kavsar',
#  '42Shared',
#  '42Southern',
#  '42Traktir',
#  '43,000S',
#  '4320/7000T',
#  '43A',
#  '43Craft',
#  '43Fusion',
#  '43Ichan',
#  '43Khodja',
#  '43Komil',
#  '43Samarkand',
#  '44/Abit',
#  '440T',
#  '4443/9774T',
#  '4499/2898T',
#  '4499T',
#  '44Alt',
#  '44Dushanbe',
#  '44Hot',
#  '44Korean',
#  '44Lyabi',
#  '44Metro',
#  '44Mirzo',
#  '45,000-60,000S',
#  '45,000S',
#  ...]

# %%
sorted(w for w in set(text1) if w.isdigit())
# Out:
# ['0',
#  '00',
#  '0000',
#  '001',
#  '0024',
#  '003',
#  '0035',
#  '005',
#  '0055',
#  '007',
#  '0070',
#  '0072',
#  '0073',
#  '0074',
#  '0088',
#  '0095',
#  '0098',
#  '01',
#  '0102',
#  '0108',
#  '011',
#  '0114',
#  '0123',
#  '014',
#  '0145',
#  '014593',
#  '0155',
#  '0191',
#  '02',
#  '020',
#  '022',
#  '0246',
#  '0258',
#  '03',
#  '0305',
#  '0373',
#  '0390',
#  '04',
#  '05',
#  '0500',
#  '053',
#  '0545',
#  '0553',
#  '0577',
#  '0599',
#  '06',
#  '0641',
#  '066',
#  '0680',
#  '07',
#  '0708',
#  '072546',
#  '0737',
#  '075',
#  '076',
#  '077',
#  '0774',
#  '08',
#  '0800',
#  '0808',
#  '0822',
#  '09',
#  '0909',
#  '091752',
#  '0998',
#  '1',
#  '10',
#  '100',
#  '1000',
#  '1004',
#  '101',
#  '1011',
#  '1013',
#  '1014',
#  '1015',
#  '1018',
#  '101933',
#  '102',
#  '1020',
#  '103',
#  '1037',
#  '104',
#  '105',
#  '1050',
#  '106',
#  '107',
#  '107340',
#  '108',
#  '1088',
#  '109',
#  '1099',
#  '11',
#  '110',
#  '1103',
#  '1107',
#  '111',
#  '112',
#  '1127',
#  '113',
#  '1130',
#  '1131',
#  '1133',
#  '114',
#  '1141',
#  '1142',
#  '115',
#  '1157',
#  '116',
#  '1166',
#  '117',
#  '1172',
#  '118',
#  '1188',
#  '119',
#  '12',
#  '120',
#  '1200',
#  '121',
#  '1210',
#  '1211',
#  '1218',
#  '1219',
#  '122',
#  '1220',
#  '1221',
#  '1223',
#  '1227',
#  '123',
#  '1234',
#  '124',
#  '125',
#  '127',
#  '1273',
#  '128',
#  '1289',
#  '129',
#  '1299',
#  '13',
#  '130',
#  '1300',
#  '131',
#  '1310',
#  '132',
#  '1326',
#  '133',
#  '1336',
#  '1338',
#  '134',
#  '1343',
#  '1350',
#  '136',
#  '1363',
#  '137',
#  '1370',
#  '1372',
#  '1374',
#  '138',
#  '1380',
#  '1383',
#  '1387',
#  '1388',
#  '1389',
#  '139',
#  '1391',
#  '1392',
#  '1394',
#  '1395',
#  '1398',
#  '14',
#  '140',
#  '1400',
#  '1401',
#  '1402',
#  '1404',
#  '1405',
#  '141',
#  '1417',
#  '142',
#  '1420',
#  '1424',
#  '1427',
#  '143',
#  '1434',
#  '1438',
#  '144',
#  '1447',
#  '1449',
#  '145',
#  '1468',
#  '147',
#  '148',
#  '1483',
#  '149',
#  '1496',
#  '1497',
#  '15',
#  '150',
#  '1500',
#  '1501',
#  '1503020',
#  '1511',
#  '152',
#  '1521',
#  '1526',
#  '1530',
#  '1535',
#  '1538',
#  '154',
#  '155',
#  '156',
#  '1569',
#  '158',
#  '1584',
#  '1592',
#  '1598',
#  '16',
#  '160',
#  '1600',
#  '161',
#  '1616',
#  '162',
#  '1620',
#  '1622',
#  '163344',
#  '1636',
#  '164',
#  '165',
#  '1657',
#  '1660',
#  '167',
#  '168',
#  '1685',
#  '169',
#  '1690',
#  '17',
#  '170',
#  '1700',
#  '1708',
#  '171',
#  '1717',
#  '1718',
#  '1720',
#  '1726',
#  '1729',
#  '173',
#  '1731',
#  '174',
#  '1740',
#  '1742',
#  '1747',
#  '175',
#  '1753',
#  '1758',
#  '176',
#  '1762',
#  '177',
#  '1771',
#  '1777',
#  '178',
#  '179',
#  '1791',
#  '1792',
#  '1799',
#  '18',
#  '180',
#  '1801',
#  '1807',
#  '1809',
#  '181',
#  '1812',
#  '1813',
#  '1818',
#  '181808',
#  '182',
#  '1822',
#  '1825',
#  '1826',
#  '1828',
#  '183',
#  '1830',
#  '1832',
#  '1836',
#  '1839',
#  '1840',
#  '1841',
#  '1842',
#  '1848',
#  '185',
#  '1851',
#  '1853',
#  '1854',
#  '1855',
#  '1856',
#  '1857',
#  '1859',
#  '186',
#  '1861',
#  '1862',
#  '1864',
#  '1865',
#  '1867',
#  '1868',
#  '1869',
#  '187',
#  '1870',
#  '1872',
#  '1873',
#  '1875',
#  '1877',
#  '1878',
#  '1879',
#  '188',
#  '1881',
#  '1882',
#  '1883',
#  '1884',
#  '1885',
#  '1887',
#  '1888',
#  '189',
#  '1890',
#  '1891',
#  '1892',
#  '1893',
#  '1895',
#  '1897',
#  '1898',
#  '19',
#  '190',
#  '1900',
#  '1901',
#  '1902',
#  '1903',
#  '1904',
#  '1906',
#  '1907',
#  '1908',
#  '1909',
#  '191',
#  '1910',
#  '1911',
#  '1912',
#  '1913',
#  '1914',
#  '1916',
#  '1917',
#  '1918',
#  '1919',
#  '1920',
#  '1921',
#  '1924',
#  '1925',
#  '1926',
#  '1927',
#  '1928',
#  '1929',
#  '193',
#  '1930',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1936',
#  '1937',
#  '1938',
#  '194',
#  '1940',
#  '1941',
#  '1942',
#  '1943',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1951',
#  '1954',
#  '1955',
#  '1956',
#  '1958',
#  '196',
#  '1960',
#  '1961',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '197',
#  '1970',
#  '1971',
#  '1972',
#  '1974',
#  '1975',
#  '1976',
#  '1978',
#  '1979',
#  '198',
#  '1980',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '201',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '202',
#  '2020',
#  '2021',
#  '2025',
#  '203',
#  '2030',
#  '204',
#  '205',
#  '2050',
#  '206',
#  '207',
#  '2083',
#  '209',
#  '21',
#  '210',
#  '212',
#  '213',
#  '214',
#  '217',
#  '218',
#  '2189',
#  '22',
#  '220',
#  '222',
#  '2221',
#  '2232',
#  '224',
#  '225',
#  '226',
#  '227',
#  '229',
#  '2297',
#  '23',
#  '230',
#  '2300',
#  '2304',
#  '231',
#  '2311',
#  '232',
#  '2326',
#  '233',
#  '234',
#  '235',
#  '2361',
#  '237',
#  '2391',
#  '24',
#  '240',
#  '2400',
#  '241',
#  '242',
#  '243',
#  '244',
#  '2441',
#  '245',
#  '246',
#  '247',
#  '249',
#  '25',
#  '250',
#  '2500',
#  '251',
#  '252',
#  '254',
#  '2545',
#  '255',
#  '2552',
#  '2558',
#  '256',
#  '258',
#  '26',
#  '260',
#  '260943',
#  '261',
#  '2611',
#  '262',
#  '263',
#  '264',
#  '2640',
#  '265',
#  '266',
#  '267',
#  '268',
#  '269',
#  '27',
#  '270',
#  '271',
#  '272',
#  '273',
#  '274',
#  '275',
#  '2750',
#  '276',
#  '277',
#  '2772',
#  '2788',
#  '279',
#  '28',
#  '280',
#  '2801',
#  '282',
#  '2829',
#  '285',
#  '2888',
#  '29',
#  '2901',
#  '291',
#  '293',
#  '2936',
#  '294',
#  '2949',
#  '295',
#  '296',
#  '2974',
#  '299',
#  '3',
#  '30',
#  '300',
#  '3000',
#  '301',
#  '302',
#  '303',
#  '3030',
#  '304',
#  '304114',
#  '305',
#  '305239',
#  '3053',
#  '307',
#  '309',
#  '3090',
#  '31',
#  '310',
#  '312',
#  '313',
#  '3138',
#  '3139',
#  '314',
#  '315',
#  '316',
#  '318',
#  '32',
#  '320',
#  '322',
#  '3222',
#  '3228',
#  '323',
#  '3230',
#  '3233',
#  '3234',
#  '3243',
#  '3262',
#  '327',
#  '328',
#  '328228',
#  '329',
#  '33',
#  '330',
#  '331',
#  '332',
#  '3322',
#  '333',
#  '3330',
#  '336',
#  '3376',
#  '338',
#  '3390',
#  '3391',
#  '3399',
#  '34',
#  '341',
#  '3422',
#  '3428',
#  '3454',
#  '346',
#  '3462',
#  '347',
#  '3475',
#  '3479',
#  '348',
#  '3494',
#  '35',
#  '350',
#  '3500',
#  '352',
#  '3522',
#  '353',
#  '3535',
#  '3536',
#  '355',
#  '3552',
#  '3553',
#  '3554',
#  '3556',
#  '358',
#  '36',
#  '360',
#  '362',
#  '363',
#  '364',
#  '365',
#  '368',
#  '37',
#  '370',
#  '3700',
#  '371',
#  '372',
#  '3720',
#  '3722',
#  '373',
#  '3736',
#  '3738',
#  '3750',
#  '3767',
#  '377',
#  '3771',
#  '378',
#  '3780',
#  '379',
#  '38',
#  '380',
#  '3800',
#  '3826',
#  '383',
#  '3836',
#  '3857',
#  '386',
#  '388',
#  '3883',
#  '39',
#  '390',
#  '391',
#  '3922',
#  '393',
#  '394',
#  '3943',
#  '3946',
#  '3947',
#  '395',
#  '396',
#  '4',
#  '40',
#  '400',
#  '4000',
#  '4012',
#  '4013',
#  '402',
#  '4034',
#  '404',
#  '4040',
#  '4050',
#  '406',
#  '407',
#  '4072',
#  '4081',
#  '41',
#  '4108',
#  '418',
#  '419',
#  '42',
#  '422',
#  '4233',
#  '4248',
#  '425',
#  '428',
#  '43',
#  '430',
#  '431',
#  '4343',
#  '436',
#  '438880',
#  '44',
#  '441',
#  '4414',
#  '4422',
#  '4455',
#  '446',
#  '4462',
#  '449',
#  '45',
#  '450',
#  '4500',
#  '4510',
#  '4520',
#  '453',
#  '454',
#  '456',
#  '46',
#  '460',
#  '47',
#  '4700',
#  '4713',
#  '4726',
#  '473391',
#  '474',
#  '476',
#  '477',
#  '48',
#  '480',
#  '4800',
#  '4803',
#  '481774',
#  '482685',
#  '487',
#  '489',
#  '49',
#  '490',
#  '4921',
#  '497777',
#  '499',
#  '5',
#  '50',
#  '500',
#  '5000',
#  '5011',
#  '503076',
#  '5037',
#  '5038',
#  '5042',
#  '51',
#  '510',
#  '5100',
#  '5101',
#  '513',
#  '514',
#  '52',
#  '5200',
#  '522',
#  '53',
#  '530',
#  '531',
#  '534',
#  '537',
#  '54',
#  '5400',
#  '5406',
#  '545',
#  '55',
#  '550',
#  '5500',
#  '551',
#  '5519',
#  '552',
#  '5530372311',
#  '5535',
#  '5544',
#  '555',
#  '5554',
#  '5555',
#  '556',
#  '557',
#  '558',
#  '559',
#  '56',
#  '5643',
#  '565',
#  '568',
#  '57',
#  '570',
#  '572',
#  '573',
#  '574',
#  '575',
#  '5777',
#  '5781',
#  '5799',
#  '58',
#  '580',
#  '581',
#  '582',
#  '5820',
#  '5863',
#  '59',
#  '5900',
#  '593',
#  '5999',
#  '6',
#  '60',
#  '600',
#  '6000',
#  '602',
#  '6036',
#  '606',
#  '6068',
#  '607',
#  '61',
#  '610',
#  '6111',
#  '612',
#  '6130',
#  '62',
#  '622',
#  '6248',
#  '6255',
#  '63',
#  '630',
#  '632',
#  '637',
#  '64',
#  '6400',
#  '642',
#  '6474',
#  '6487',
#  '65',
#  '6500',
#  '652005',
#  '6555',
#  '658',
#  '659',
#  '66',
#  '6605',
#  '661',
#  '662',
#  '662329',
#  '6632',
#  '663737',
#  '6666',
#  '6668',
#  '668',
#  '6688',
#  '67',
#  '670',
#  '6711',
#  '6748',
#  '6768',
#  '6772',
#  '68',
#  '680',
#  '681',
#  '6813',
#  '69',
#  '6912',
#  '693',
#  '6942',
#  '697101',
#  '6999',
#  '7',
#  '70',
#  '700',
#  '7000',
#  '7009',
#  '701',
#  '702',
#  '7030',
#  '705',
#  '706',
#  '707',
#  '7070',
#  '7077',
#  '708',
#  '709',
#  '71',
#  '7100',
#  '711',
#  '7112',
#  '711210',
#  '712',
#  '713',
#  '715',
#  '716',
#  '71630',
#  '71636',
#  '71637',
#  '717',
#  '7171',
#  '7172',
#  '718',
#  '719',
#  '72',
#  '720',
#  '721',
#  '7212',
#  '72156',
#  '7222',
#  '72251',
#  '7232',
#  '724',
#  '7242',
#  '72433',
#  '725',
#  '7252',
#  '72533',
#  '72538',
#  '72544',
#  '726',
#  '7262',
#  '7268',
#  '727',
#  '72777',
#  '7292',
#  '72934',
#  '73',
#  '730',
#  '731',
#  '733',
#  '7340',
#  '737',
#  '74',
#  '742',
#  '746202',
#  '75',
#  '750',
#  '751',
#  '75247',
#  '7539',
#  '755',
#  '7557',
#  '7571',
#  '759',
#  '76',
#  '7602',
#  '7610',
#  '764',
#  '77',
#  '770240284',
#  '771',
#  '772',
#  '7723',
#  '7729',
#  '775',
#  '776',
#  '7762',
#  '7766',
#  '777',
#  '7770',
#  '7772',
#  '7777',
#  '778',
#  '7788',
#  '78',
#  '79',
#  '793',
#  '7969',
#  '798',
#  '8',
#  '80',
#  '800',
#  '8000',
#  '8020',
#  '803300',
#  '8046',
#  '8056',
#  '8080',
#  '8083',
#  '81',
#  '8111',
#  '8189',
#  '82',
#  '822',
#  '83',
#  '8300',
#  '8337',
#  '836',
#  '8379',
#  '84',
#  '847',
#  '85',
#  '850',
#  '8555',
#  '8558',
#  ...]

# %%
len(text1)
# Out:
# 315725

# %%
len(set(text1))
# Out:
# 31504

# %%
len(set(word.lower() for word in text1))
# Out:
# 28636

# %% [markdown]
# Now that we are not double-counting words like This and this, which differ only in capitalization, we've wiped 2,000 off the vocabulary count! We can go a step further and eliminate numbers and punctuation from the vocabulary count by filtering out any non-alphabetic items:

# %%
len(set(word.lower() for word in text1 if word.isalpha())) #only alphabetical words
# Out:
# 18238

# %% [markdown]
# # 2. Accessing Text Corpora and Lexical Resources
#
# This program displays three statistics for each text: average word length, average sentence length, and the number of times each vocabulary item appears in the text on average (our lexical diversity score). Observe that average word length appears to be a general property of English, since it has a recurrent value of 4. (In fact, the average word length is really 3 not 4, since the num_chars variable counts space characters.) By contrast average sentence length and lexical diversity appear to be characteristics of particular authors.

# %%
from nltk.corpus import gutenberg
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
for fileid in gutenberg.fileids():
    num_chars = len(gutenberg.raw(fileid))
    num_words = len(gutenberg.words(fileid))
    num_sents = len(gutenberg.sents(fileid))
    num_vocab = len(set(w.lower() for w in gutenberg.words(fileid)))
    print(round(num_chars/num_words), round(num_words/num_sents), round(num_words/num_vocab), fileid)
# Out:
# 5 25 26 austen-emma.txt
# 5 26 17 austen-persuasion.txt
# 5 28 22 austen-sense.txt
# 4 34 79 bible-kjv.txt
# 5 19 5 blake-poems.txt
# 4 19 14 bryant-stories.txt
# 4 18 12 burgess-busterbrown.txt
# 4 20 13 carroll-alice.txt
# 5 20 12 chesterton-ball.txt
# 5 23 11 chesterton-brown.txt
# 5 18 11 chesterton-thursday.txt
# 4 21 25 edgeworth-parents.txt
# 5 26 15 melville-moby_dick.txt
# 5 52 11 milton-paradise.txt
# 4 12 9 shakespeare-caesar.txt
# 4 12 8 shakespeare-hamlet.txt
# 4 12 7 shakespeare-macbeth.txt
# 5 36 12 whitman-leaves.txt

# %% [markdown]
# Man without Qualities:

# %%
chars = len(moe_txt)
words = len(moe)

moe_sents = sent_tokenize(moe_txt)
sents = len(moe_sents)

vocab = len(set(w.lower() for w in moe))

print("Average word length:", chars / words)
print("Average sentence length:", words / sents)
print("Lexical diversity score:", words / vocab)
# Out:
# Average word length: 5.531424380476372
# Average sentence length: 29.35391274632646
# Lexical diversity score: 15.21539067112773

# %% [markdown]
# Lonely Planet Central Asia:

# %%
chars = len(file_contents)
words = len(text1)

lp_sents = sent_tokenize(file_contents)
sents = len(lp_sents)

vocab = len(set(w.lower() for w in text1))

print("Average word length:", chars / words)
print("Average sentence length:", words / sents)
print("Lexical diversity score:", words / vocab)
# Out:
# Average word length: 5.3717095573679625
# Average sentence length: 28.31360416106179
# Lexical diversity score: 11.025457466126554

# %% [markdown]
# The Brown Corpus is a convenient resource for studying systematic differences between genres, a kind of linguistic inquiry known as stylistics. Let's compare genres in their usage of modal verbs. The first step is to produce the counts for a particular genre. Remember to import nltk before doing the following:

# %%
from nltk.corpus import brown

news_text = brown.words(categories='news')
fdist = FreqDist(w.lower() for w in news_text)
modals = ['can', 'could', 'may', 'might', 'must', 'will']

for m in modals:
    print(m + ':', fdist[m], end=' ')
# Out:
# can: 94 could: 87 may: 93 might: 38 must: 53 will: 389

# %% [markdown]
# Observe that the most frequent modal in the news genre is will, while the most frequent modal in the romance genre is could. Would you have predicted this? The idea that word counts might distinguish genres will be taken up again in chap-data-intensive.
#
# The Reuters Corpus contains 10,788 news documents totaling 1.3 million words. The documents have been classified into 90 topics, and grouped into two sets, called "training" and "test"; thus, the text with fileid 'test/14826' is a document drawn from the test set. This split is for training and testing algorithms that automatically detect the topic of a document, as we will see in chap-data-intensive.
#
# Similarly, we can specify the words or sentences we want in terms of files or categories. The first handful of words in each of these texts are the titles, which by convention are stored as upper case.

# %% [markdown]
# Let's look at how the words America and citizen are used over time. The following code converts the words in the Inaugural corpus to lowercase using  w.lower() [1], then checks if they start with either of the "targets" america or  citizen using startswith() [1]. Thus it will count words like American's and Citizens. We'll learn about conditional frequency distributions in 2; for now just consider the output, shown in 1.1.

# %%
from nltk.corpus import inaugural

cfd = ConditionalFreqDist(
    (target, fileid[:4])
    for fileid in inaugural.fileids()
    for w in inaugural.words(fileid)
    for target in ['america', 'citizen']
    if w.lower().startswith(target))

cfd.plot()

# %% [markdown]
# The last of these corpora, udhr, contains the Universal Declaration of Human Rights in over 300 languages. The fileids for this corpus include information about the character encoding used in the file, such as UTF8 or Latin1. Let's use a conditional frequency distribution to examine the differences in word lengths for a selection of languages included in the udhr corpus. The output is shown in 1.2 (run the program yourself to see a color plot). Note that True and  False are Python's built-in boolean values.

# %%
from nltk.corpus import udhr

languages = ['Chickasaw', 'English', 'German_Deutsch', 'Greenlandic_Inuktikut', 'Hungarian_Magyar', 'Ibibio_Efik']

cfd = ConditionalFreqDist(
    (lang, len(word))
    for lang in languages
    for word in udhr.words(lang + '-Latin1'))

cfd.plot(cumulative=True)

# %% [markdown]
# this graph shows that words having 5 or fewer letters account for about 80% of Ibibio text, 60% of German text, and 25% of Inuktitut text.

# %% [markdown]
# ## how to load own corpus:
# If you have your own collection of text files that you would like to access using the above methods, you can easily load them with the help of NLTK's PlaintextCorpusReader. Check the location of your files on your file system; in the following example, we have taken this to be the directory /usr/share/dict. Whatever the location, set this to be the value of corpus_root [1]. The second parameter of the PlaintextCorpusReader initializer [2] can be a list of fileids, like ['a.txt', 'test/b.txt'], or a pattern that matches all fileids, like '[abc]/.*\.txt' (see 3.4 for information about regular expressions).

# %%
>>> from nltk.corpus import PlaintextCorpusReader
>>> corpus_root = '/usr/share/dict' [1]
>>> wordlists = PlaintextCorpusReader(corpus_root, '.*') [2]
>>> wordlists.fileids()
['README', 'connectives', 'propernames', 'web2', 'web2a', 'words']
>>> wordlists.words('connectives')
['the', 'of', 'and', 'to', 'a', 'in', 'that', 'is', ...]
